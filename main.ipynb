# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

# %%
data = pd.read_excel("donnees_agricoles_nettoyees.xlsx")

# %%
data.head()
# Out:
#    annee   campagne departement culture localite localite_normalisee  \
# 0   1995  1995-1996      BORGOU    Maïs   BORGOU              BORGOU
# 1   1996  1996-1997      BORGOU    Maïs   BORGOU              BORGOU
# 2   1997  1997-1998      BORGOU    Maïs   BORGOU              BORGOU
# 3   1998  1998-1999      BORGOU    Maïs   BORGOU              BORGOU
# 4   1999  1999-2000      BORGOU    Maïs   BORGOU              BORGOU
#
#    superficie_ha  rendement_kg_ha  rendement_t_ha  production_t  \
# 0        64119.0      1147.787707        1.147788       73595.0
# 1        60840.0      1101.298488        1.101298       67003.0
# 2        65993.0      1165.684239        1.165684       76927.0
# 3        71639.0      1192.967518        1.192968       85463.0
# 4        76186.0      1220.473578        1.220474       92983.0
#
#   source_feuille  ligne_source  colonne_source       niveau
# 0           Maïs            20               3  departement
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("heart+(2).csv")
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(data['Age'])
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.scatter(data['Age'], data['MaxHR'])
plt.xlabel('Age')
plt.ylabel('MaxHR')
plt.title('Age vs MaxHR')
# Out:
# Text(0.5, 1.0, 'Age vs MaxHR')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=data, x="Age", y="MaxHR", hue="Sex")
plt.show()

# %%
import seaborn as sns

# %%
sns.regplot(data=data, x="Age", y="MaxHR")
# Out:
# <Axes: xlabel='Age', ylabel='MaxHR'>

# %%
sns.kdeplot(data=data, x="Age", hue="HeartDisease", fill=True)
sns.set_theme(style="whitegrid")

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
import plotly.express as px

fig = px.bar(data, x="ChestPainType", color="HeartDisease", barmode="group",
             title="Répartition des types de douleur thoracique selon le diagnostic")
fig.show()

# %%
table = pd.crosstab(data["RestingECG"], data["HeartDisease"])
fig = px.imshow(table, text_auto=True, title="Composition des résultats d'ECG")
fig.show()

# %%
import scipy.stats as st
import numpy as np

print(st.pearsonr(depenses["solde_avt_ope"],-depenses["montant"])[0])
print(np.cov(depenses["solde_avt_ope"],-depenses["montant"],ddof=0)[1,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import scipy.stats as st
#       2 import numpy as np
#       3
# ----> 4 print(st.pearsonr(depenses["solde_avt_ope"],-depenses["montant"])[0])
#       5 print(np.cov(depenses["solde_avt_ope"],-depenses["montant"],ddof=0)[1,0])
#
# NameError: name 'depenses' is not defined

# %%
import scipy.stats as st
import numpy as np

print(st.pearsonr(depenses["solde_avt_ope"],-depenses["montant"])[0])
print(np.cov(depenses["solde_avt_ope"],-depenses["montant"],ddof=0)[1,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import scipy.stats as st
#       2 import numpy as np
#       3
# ----> 4 print(st.pearsonr(depenses["solde_avt_ope"],-depenses["montant"])[0])
#       5 print(np.cov(depenses["solde_avt_ope"],-depenses["montant"],ddof=0)[1,0])
#
# NameError: name 'depenses' is not defined
